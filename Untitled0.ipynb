# %% [markdown]
# <a href="https://colab.research.google.com/github/JCruz-debug/SistemasOperativos2496/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

# %%
def MostrarPCB(Pid,Etiqueta):
  Campos = [
      "Name",
      "State",
      "Pid",
      "PPid",
      "VmSize",
      "VmRS",
      "Voluntary_ctxt_switches",
  ]

  print(f"Mostrando PCB de {Etiqueta}")

  for campo in Campos:
    with open(f"/proc/{Pid}/status") as F:
      for Linea in F:
        if Linea.startswith(campo):
          print(f"{Linea}")

# %%
print("Practica 1 - Inspeccion de PCB de padre e hijo")

print(f"PADRE PID {os.getpid()}")
MostrarPCB(os.getpid(), "PROCESO PADRE")

Pid = os.fork()
# Out:
# Practica 1 - Inspeccion de PCB de padre e hijo
# PADRE PID 582
# Mostrando PCB de PROCESO PADRE
# Name:	python3
#
# State:	R (running)
#
# Pid:	582
#
# PPid:	86
#
# VmSize:	  769600 kB
#
# VmRSS:	  194004 kB
# /tmp/ipython-input-279580856.py:6: DeprecationWarning: This process (pid=582) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   Pid = os.fork()
# Practica 1 - Inspeccion de PCB de padre e hijo
# PADRE PID 582
# Mostrando PCB de PROCESO PADRE
# Name:	python3
#
# State:	R (running)
#
# Pid:	582
#
# PPid:	86
#
# VmSize:	  769600 kB
#
# VmRSS:	  194004 kB

# %%
print("Creando Proceso Hijo")
Pid = os.fork()
print(f"Estado {Pid}")

if Pid == 0:
  print(f"SOY EL HIJO")
  print(f"[HIJO] PID {os.getpid()} ")
  print(f"[HIJO] PPID {os.getppid()} ")
  print(f"[HIJO] Mostrando mi PCB...")
  MostrarPCB(os.getpid(), "HIJO")

  sys.exit(0) #Finaliza el proceso

else:
  print(f"[PADRE] soy el padre de {Pid}")

os.waitpid(Pid,0) #Cosecha al hijo y libera su PCB
# Out:
# Creando Proceso Hijo
# Estado 0
# SOY EL HIJO
# [HIJO] PID 13750
# [HIJO] PPID 582
# [HIJO] Mostrando mi PCB...
# Creando Proceso Hijo
# Estado 13750
# [PADRE] soy el padre de 13750
# Mostrando PCB de HIJO
# /tmp/ipython-input-3822951932.py:2: DeprecationWarning: This process (pid=582) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   Pid = os.fork()
# Name:	python3
#
# State:	R (running)
#
# Pid:	13750
#
# PPid:	582
#
# VmSize:	  728620 kB
#
# VmRSS:	  162884 kB
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3822951932.py in <cell line: 0>()
#      15   print(f"[PADRE] soy el padre de {Pid}")
#      16
# ---> 17 os.waitpid(Pid,0) #Cosecha al hijo y libera su PCB
#
# KeyboardInterrupt:

# %%
def MostrarEstado(Pid, Etiqueta):
  with open(f"/proc/{pid}/status") as F:
    for L
